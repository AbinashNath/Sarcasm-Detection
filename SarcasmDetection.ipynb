# %%
import numpy as np 
import pandas as pd 
import os
import re
import matplotlib.pyplot as plt
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, GRU, LSTM, Bidirectional
from keras.layers.embeddings import Embedding
from keras.initializers import Constant
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import tensorflow as tf
from keras.utils import plot_model
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# Out:
# --2021-05-12 04:44:44--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2021-05-12 04:44:44--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2021-05-12 04:44:44--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip.1’
#
# glove.6B.zip.1      100%[===================>] 822.24M  5.12MB/s    in 2m 40s
#
# 2021-05-12 04:47:24 (5.15 MB/s) - ‘glove.6B.zip.1’ saved [862182613/862182613]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data1 =  pd.read_json( '/content/drive/MyDrive/MyDrive/demo.json', lines=True)

data2 =  pd.read_json( '/content/drive/MyDrive/MyDrive/Sarcasm_Headlines_Dataset_v2.json', lines=True)
data= pd.concat([data1,data2])
data.head()
# Out:
#   article_link                                           headline  is_sarcastic
# 0     TrainSen  @0430yes i hope you are lurking right now. i w...             0
# 1     TrainSen  05 really taught me a valuable lesson I'm neve...             0
# 2     TrainSen  @098BERRY Never had a voice to protest, so you...             0
# 3     TrainSen  @0hMySt4rs Rest in peace & love to you and you...             0
# 4     TrainSen  100 days until Christmas! 🌲 #too soon #not rea...             0

# %%
# !unzip glove*.zip
# Out:
# Archive:  glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt

# %%
embeddings_index = {}
embedding_dim = 100
f = open('glove.6B.100d.txt')
for line in f:
  values = line.split()
  word = values[0]
  coefs = np.asarray(values[1:], dtype='float32')
  embeddings_index[word] = coefs
f.close()
print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
from collections import defaultdict
abb_dict=defaultdict()
hash_dict=defaultdict()
off_dict=defaultdict()
emo_dict=defaultdict()
spell_dict=defaultdict()
def loadEmo():
  with open("/content/drive/MyDrive/MyDrive/emoji.txt") as fp:
    lines=fp.readlines()
    for l in lines:
      token=l.lower().strip().split('\t')
      emo_dict[token[0]]=token[1]
  return


def loadOff():
  with open("/content/drive/MyDrive/MyDrive/Off.txt") as fp:
    lines=fp.readlines()
    for l in lines:
      token=l.lower().strip()
      off_dict[token]="value"
  return


def loadHash():
  with open("/content/drive/MyDrive/MyDrive/hsh.txt") as fp:
    lines=fp.readlines()
    for l in lines:
      token=l.lower().strip().split('\t')
      hash_dict[token[0]]=token[1]
  return
def loadAbb():
  with open("/content/drive/MyDrive/MyDrive/abb.txt") as fp:
    lines=fp.readlines()
    for l in lines:
      token=l.lower().strip().split('\t')
      abb_dict[token[0]]=token[1]
  return
def loadSpell():
  with open("/content/drive/MyDrive/MyDrive/spell.txt") as fp:
    lines=fp.readlines()
    for l in lines:
      token=l.lower().strip().split('\t')
      spell_dict[token[0]]=token[1]
  return

# %%
def rem_abb(text):
  splits=text.split()
  for t in splits:
    if(t in abb_dict):
      text=re.sub(r"{}".format(t),"{}".format(abb_dict.get(t)),text)
  return text

def rem_hash(text):
  splits=text.split()
  for t in splits:
    ##print(t)
    if(t in hash_dict):
      text=re.sub(r"{}".format(t),"{}".format(hash_dict.get(t)),text)
  return text

def rem_emo(text):
  splits=text.split()
  for t in splits:
    if(t in emo_dict):
      text=re.sub(r"{}".format(t),"",text)
  return text
def rem_off(text):
  splits=text.split()
  for t in splits:
    if(t in off_dict):
      text=re.sub(r"{}".format(t),"",text)
  return text
def rem_spell(text):
  splits=text.split()
  for t in splits:
    if(t in spell_dict):
      text=re.sub(r"{}".format(t),"{}".format(spell_dict.get(t)),text)
  return text

# %%
def normalize_word(word):
    temp = word
    while True:
        w = re.sub(r"([a-zA-Z])\1\1", r"\1\1", temp)
        if (w == temp):
            break
        else:
            temp = w
    return w

# %%
normalize_word("i ccannnnot believe this")
# Out:
# 'i ccannot believe this'

# %%
loadAbb()
loadEmo()
loadHash()
loadOff()
loadSpell()
def proc(text):
  text=rem_hash(text)
  text=normalize_word(text)
  text=rem_spell(text)
  #text=text.lower()
  text=rem_abb(text)
  text=rem_emo(text)
  text=rem_off(text)
  return text

# %%
proc("10k walk this morning. We did an awesome job.")
# Out:
# '10k walk this morning. We did an awesome job.'

# %%
from collections import Counter
cnt=Counter()
for text in data["headline"].values:
  for word in text.split():
    cnt[word]+=1
cnt.most_common(25)
freq=set([w for (w, wc) in cnt.most_common(25)])
def fre(text):
  return " ".join([word for word in str(text).split() if word not in freq])

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.7/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.7/dist-packages (from textblob) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (1.15.0)

# %%
from textblob import TextBlob 
def spell(text):
  textBlb=TextBlob(text)
  textCorrected=textBlb.correct()
  #print(type(textCorrected))
  return str(textCorrected)

# %%
def clean_text(text):
    text = text.lower()
    text=re.sub(r","," ",text)
    text=re.sub(r"!"," ",text)
    text=re.sub(r"\."," ",text)
    text=re.sub(r"\?"," ",text)
    text= re.sub(r"#sarcasm","",text)
    #text= re.sub(r"#not","",text)
    text=re.sub(r"#sarcastictweet","",text)
    pattern = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    text = pattern.sub(' ', text)
    text = " ".join(filter(lambda x:x[0]!='@', text.split()))
    text=proc(text)
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)        
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text) 
    text = re.sub(r"\'ll", " will", text)  
    text = re.sub(r"\'ve", " have", text)  
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"don't", "do not", text)
    text = re.sub(r"did't", "did not", text)
    text = re.sub(r"can't", "can not", text)
    text = re.sub(r"it's", "it is", text)
    text = re.sub(r"couldn't", "could not", text)
    text = re.sub(r"have't", "have not", text)
    #text=re.sub(r"sarcasm","",text)
    text = re.sub(r"[,.\"\'!@#$%^&*(){}?/;`~:<>+=-]", " ", text)
    return text

# %%
clean_text("10k walk this morning. We did an awesome job.")
# Out:
# '10k walk this morning we did an awesome job'

# %%
import nltk
import gensim
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
from gensim.parsing.preprocessing import remove_stopwords, STOPWORDS
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
def cln_tkn(token):
  return [i for i in token if len(i)>2]

# %%
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

def CleanTokenize(df):
    head_lines = list()
    lines = df["headline"].values.tolist()

    for line in lines:
        line = clean_text(line)
        line=remove_stopwords(line)
        word_list=nltk.word_tokenize(line)
        lemmatizer=WordNetLemmatizer()
        line=" ".join([lemmatizer.lemmatize(w) for w in word_list])
        line=fre(line)
        #line=spell(line)
        # tokenize the text
        tokens = word_tokenize(line)
        #tokens=cln_tkn(tokens)
        # remove puntuations
        table = str.maketrans('', '', string.punctuation)
        stripped = [w.translate(table) for w in tokens]
        # remove non alphabetic characters
        words = [word for word in stripped if word.isalpha()]
        stop_words = set(stopwords.words("english"))
        # remove stop words
        ##words = [w for w in words if not w in stop_words]
        head_lines.append(words)
    return head_lines

head_lines = CleanTokenize(data)
head_lines[0:10]
# Out:
# [['hope',
#   'lurking',
#   'right',
#   'want',
#   'listen',
#   'hallucination',
#   'want',
#   'live',
#   'someday',
#   'pretty'],
#  ['taught', 'valuable', 'lesson', 'going', 'late'],
#  ['voice',
#   'protest',
#   'fed',
#   'digest',
#   'wish',
#   'reason',
#   'flaw',
#   'open',
#   'season'],
#  ['rest', 'peace', 'family'],
#  ['day', 'christmas', 'soon', 'ready'],
#  ['happy', 'wait', 'reunited', 'honey', 'xx'],
#  ['word',
#   'short',
#   'word',
#   'requirement',
#   'care',
#   'going',
#   'bed',
#   'rebel',
#   'hate',
#   'history'],
#  ['nice', 'hanging', 'afternoon', 'great', 'time'],
#  ['walk', 'morning', 'awesome', 'job'],
#  ['minute', 'eat', 'challenge', 'accepted']]

# %%
from collections import Counter
from wordcloud import WordCloud, ImageColorGenerator
pos_data = data.loc[data['is_sarcastic'] == 1]
pos_head_lines = CleanTokenize(pos_data)
pos_lines = [j for sub in pos_head_lines for j in sub] 
word_could_dict=Counter(pos_lines)

wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(word_could_dict)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 999.5, 499.5, -0.5)

# %%
validation_split = 0.2
max_length = 25


tokenizer_obj = Tokenizer()
tokenizer_obj.fit_on_texts(head_lines)
sequences = tokenizer_obj.texts_to_sequences(head_lines)

word_index = tokenizer_obj.word_index
print("unique tokens - ",len(word_index))
vocab_size = len(tokenizer_obj.word_index) + 1
print('vocab size -', vocab_size)

lines_pad = pad_sequences(sequences, maxlen=max_length, padding='post')
sentiment =  data['is_sarcastic'].values

indices = np.arange(lines_pad.shape[0])
np.random.shuffle(indices)
lines_pad = lines_pad[indices]
sentiment = sentiment[indices]

num_validation_samples = int(validation_split * lines_pad.shape[0])

X_train_pad = lines_pad[:-num_validation_samples]
y_train = sentiment[:-num_validation_samples]
X_test_pad = lines_pad[-num_validation_samples:]
y_test = sentiment[-num_validation_samples:]
# Out:
# unique tokens -  32786
# vocab size - 32787

# %%
print('Shape of X_train_pad:', X_train_pad.shape)
print('Shape of y_train:', y_train.shape)

print('Shape of X_test_pad:', X_test_pad.shape)
print('Shape of y_test:', y_test.shape)
# Out:
# Shape of X_train_pad: (71063, 25)
# Shape of y_train: (71063,)
# Shape of X_test_pad: (17765, 25)
# Shape of y_test: (17765,)

# %%
embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
c = 0
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        c+=1
        embedding_matrix[i] = embedding_vector
print(c)
# Out:
# 27073

# %%
embedding_layer = Embedding(len(word_index) + 1,
                            embedding_dim,
                            weights=[embedding_matrix],
                            input_length=max_length,
                            trainable=False)

# %%
from keras import Sequential, Model
from keras.layers import Embedding,LSTM, GlobalMaxPool1D,Dense,Dropout,Bidirectional,GRU

# %% [markdown]
# **RCNN**

# %%
rcnn= Sequential()
rcnn.add(embedding_layer)
rcnn.add(tf.keras.layers.Conv1D(128,1,activation='relu'))
rcnn.add(tf.keras.layers.MaxPooling1D(2,padding='same'))
rcnn.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)))
rcnn.add(tf.keras.layers.Dense(100,kernel_regularizer=tf.keras.regularizers.l1(0.005),activation='relu'))
rcnn.add(tf.keras.layers.Dropout(0.5))
rcnn.add(tf.keras.layers.Dense(1, kernel_regularizer=tf.keras.regularizers.l1(0.005),activation='sigmoid'))

# %%
from keras.utils.vis_utils import plot_model
plot_model(rcnn, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
rcnn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

mcr = tf.keras.callbacks.ModelCheckpoint('model_best.hdf5', monitor='val_accuracy', 
                                        verbose=1, save_best_only=True, mode='max')
es = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", mode="max", patience=5)
    
historyr = rcnn.fit(X_train_pad, y_train,
                    epochs=40, callbacks=[mcr], 
                    validation_split=0.1, verbose=2)
# Out:
# Epoch 1/40
# 1999/1999 - 36s - loss: 0.7697 - accuracy: 0.6665 - val_loss: 0.6272 - val_accuracy: 0.6978
#
# Epoch 00001: val_accuracy improved from -inf to 0.69776, saving model to model_best.hdf5
# Epoch 2/40
# 1999/1999 - 30s - loss: 0.6136 - accuracy: 0.7255 - val_loss: 0.5925 - val_accuracy: 0.7260
#
# Epoch 00002: val_accuracy improved from 0.69776 to 0.72604, saving model to model_best.hdf5
# Epoch 3/40
# 1999/1999 - 31s - loss: 0.5831 - accuracy: 0.7533 - val_loss: 0.5726 - val_accuracy: 0.7462
#
# Epoch 00003: val_accuracy improved from 0.72604 to 0.74617, saving model to model_best.hdf5
# Epoch 4/40
# 1999/1999 - 30s - loss: 0.5610 - accuracy: 0.7708 - val_loss: 0.5873 - val_accuracy: 0.7404
#
# Epoch 00004: val_accuracy did not improve from 0.74617
# Epoch 5/40
# 1999/1999 - 31s - loss: 0.5438 - accuracy: 0.7847 - val_loss: 0.5532 - val_accuracy: 0.7583
#
# Epoch 00005: val_accuracy improved from 0.74617 to 0.75827, saving model to model_best.hdf5
# Epoch 6/40
# 1999/1999 - 30s - loss: 0.5251 - accuracy: 0.7966 - val_loss: 0.5465 - val_accuracy: 0.7676
#
# Epoch 00006: val_accuracy improved from 0.75827 to 0.76755, saving model to model_best.hdf5
# Epoch 7/40
# 1999/1999 - 31s - loss: 0.5088 - accuracy: 0.8074 - val_loss: 0.5413 - val_accuracy: 0.7711
#
# Epoch 00007: val_accuracy improved from 0.76755 to 0.77107, saving model to model_best.hdf5
# Epoch 8/40
# 1999/1999 - 31s - loss: 0.4933 - accuracy: 0.8174 - val_loss: 0.5435 - val_accuracy: 0.7719
#
# Epoch 00008: val_accuracy improved from 0.77107 to 0.77192, saving model to model_best.hdf5
# Epoch 9/40
# 1999/1999 - 31s - loss: 0.4789 - accuracy: 0.8286 - val_loss: 0.5343 - val_accuracy: 0.7736
#
# Epoch 00009: val_accuracy improved from 0.77192 to 0.77360, saving model to model_best.hdf5
# Epoch 10/40
# 1999/1999 - 31s - loss: 0.4674 - accuracy: 0.8348 - val_loss: 0.5631 - val_accuracy: 0.7721
#
# Epoch 00010: val_accuracy did not improve from 0.77360
# Epoch 11/40
# 1999/1999 - 31s - loss: 0.4551 - accuracy: 0.8423 - val_loss: 0.5485 - val_accuracy: 0.7809
#
# Epoch 00011: val_accuracy improved from 0.77360 to 0.78092, saving model to model_best.hdf5
# Epoch 12/40
# 1999/1999 - 31s - loss: 0.4420 - accuracy: 0.8513 - val_loss: 0.5403 - val_accuracy: 0.7804
#
# Epoch 00012: val_accuracy did not improve from 0.78092
# Epoch 13/40
# 1999/1999 - 31s - loss: 0.4301 - accuracy: 0.8566 - val_loss: 0.5342 - val_accuracy: 0.7888
#
# Epoch 00013: val_accuracy improved from 0.78092 to 0.78880, saving model to model_best.hdf5
# Epoch 14/40
# 1999/1999 - 30s - loss: 0.4211 - accuracy: 0.8637 - val_loss: 0.5500 - val_accuracy: 0.7827
#
# Epoch 00014: val_accuracy did not improve from 0.78880
# Epoch 15/40
# 1999/1999 - 31s - loss: 0.4128 - accuracy: 0.8673 - val_loss: 0.5493 - val_accuracy: 0.7891
#
# Epoch 00015: val_accuracy improved from 0.78880 to 0.78908, saving model to model_best.hdf5
# Epoch 16/40
# 1999/1999 - 31s - loss: 0.4034 - accuracy: 0.8725 - val_loss: 0.5448 - val_accuracy: 0.7918
#
# Epoch 00016: val_accuracy improved from 0.78908 to 0.79175, saving model to model_best.hdf5
# Epoch 17/40
# 1999/1999 - 31s - loss: 0.3946 - accuracy: 0.8785 - val_loss: 0.5438 - val_accuracy: 0.7960
#
# Epoch 00017: val_accuracy improved from 0.79175 to 0.79598, saving model to model_best.hdf5
# Epoch 18/40
# 1999/1999 - 31s - loss: 0.3879 - accuracy: 0.8808 - val_loss: 0.5573 - val_accuracy: 0.7923
#
# Epoch 00018: val_accuracy did not improve from 0.79598
# Epoch 19/40
# 1999/1999 - 31s - loss: 0.3802 - accuracy: 0.8862 - val_loss: 0.5539 - val_accuracy: 0.8026
#
# Epoch 00019: val_accuracy improved from 0.79598 to 0.80259, saving model to model_best.hdf5
# Epoch 20/40
# 1999/1999 - 31s - loss: 0.3726 - accuracy: 0.8889 - val_loss: 0.5543 - val_accuracy: 0.8002
#
# Epoch 00020: val_accuracy did not improve from 0.80259
# Epoch 21/40
# 1999/1999 - 31s - loss: 0.3684 - accuracy: 0.8924 - val_loss: 0.5632 - val_accuracy: 0.7994
#
# Epoch 00021: val_accuracy did not improve from 0.80259
# Epoch 22/40
# 1999/1999 - 31s - loss: 0.3631 - accuracy: 0.8946 - val_loss: 0.5669 - val_accuracy: 0.7998
#
# Epoch 00022: val_accuracy did not improve from 0.80259
# Epoch 23/40
# 1999/1999 - 30s - loss: 0.3557 - accuracy: 0.8992 - val_loss: 0.5737 - val_accuracy: 0.7943
#
# Epoch 00023: val_accuracy did not improve from 0.80259
# Epoch 24/40
# 1999/1999 - 30s - loss: 0.3514 - accuracy: 0.9006 - val_loss: 0.5630 - val_accuracy: 0.8033
#
# Epoch 00024: val_accuracy improved from 0.80259 to 0.80329, saving model to model_best.hdf5
# Epoch 25/40
# 1999/1999 - 30s - loss: 0.3475 - accuracy: 0.9025 - val_loss: 0.5736 - val_accuracy: 0.8001
#
# Epoch 00025: val_accuracy did not improve from 0.80329
# Epoch 26/40
# 1999/1999 - 30s - loss: 0.3427 - accuracy: 0.9045 - val_loss: 0.5814 - val_accuracy: 0.8064
#
# Epoch 00026: val_accuracy improved from 0.80329 to 0.80639, saving model to model_best.hdf5
# Epoch 27/40
# 1999/1999 - 31s - loss: 0.3392 - accuracy: 0.9071 - val_loss: 0.5761 - val_accuracy: 0.8047
#
# Epoch 00027: val_accuracy did not improve from 0.80639
# Epoch 28/40
# 1999/1999 - 31s - loss: 0.3335 - accuracy: 0.9096 - val_loss: 0.5942 - val_accuracy: 0.7988
#
# Epoch 00028: val_accuracy did not improve from 0.80639
# Epoch 29/40
# 1999/1999 - 31s - loss: 0.3314 - accuracy: 0.9116 - val_loss: 0.5805 - val_accuracy: 0.8037
#
# Epoch 00029: val_accuracy did not improve from 0.80639
# Epoch 30/40
# 1999/1999 - 31s - loss: 0.3317 - accuracy: 0.9108 - val_loss: 0.5931 - val_accuracy: 0.7978
#
# Epoch 00030: val_accuracy did not improve from 0.80639
# Epoch 31/40
# 1999/1999 - 31s - loss: 0.3240 - accuracy: 0.9150 - val_loss: 0.5799 - val_accuracy: 0.8079
#
# Epoch 00031: val_accuracy improved from 0.80639 to 0.80794, saving model to model_best.hdf5
# Epoch 32/40
# 1999/1999 - 31s - loss: 0.3197 - accuracy: 0.9160 - val_loss: 0.6033 - val_accuracy: 0.8034
#
# Epoch 00032: val_accuracy did not improve from 0.80794
# Epoch 33/40
# 1999/1999 - 35s - loss: 0.3177 - accuracy: 0.9181 - val_loss: 0.5930 - val_accuracy: 0.8024
#
# Epoch 00033: val_accuracy did not improve from 0.80794
# Epoch 34/40
# 1999/1999 - 32s - loss: 0.3141 - accuracy: 0.9187 - val_loss: 0.5960 - val_accuracy: 0.8057
#
# Epoch 00034: val_accuracy did not improve from 0.80794
# Epoch 35/40
# 1999/1999 - 31s - loss: 0.3163 - accuracy: 0.9189 - val_loss: 0.6020 - val_accuracy: 0.8057
#
# Epoch 00035: val_accuracy did not improve from 0.80794
# Epoch 36/40
# 1999/1999 - 31s - loss: 0.3099 - accuracy: 0.9222 - val_loss: 0.6274 - val_accuracy: 0.8060
#
# Epoch 00036: val_accuracy did not improve from 0.80794
# Epoch 37/40
# 1999/1999 - 30s - loss: 0.3089 - accuracy: 0.9227 - val_loss: 0.6075 - val_accuracy: 0.8095
#
# Epoch 00037: val_accuracy improved from 0.80794 to 0.80948, saving model to model_best.hdf5
# Epoch 38/40
# 1999/1999 - 31s - loss: 0.3058 - accuracy: 0.9239 - val_loss: 0.6046 - val_accuracy: 0.7989
#
# Epoch 00038: val_accuracy did not improve from 0.80948
# Epoch 39/40
# 1999/1999 - 31s - loss: 0.3049 - accuracy: 0.9246 - val_loss: 0.6025 - val_accuracy: 0.8085
#
# Epoch 00039: val_accuracy did not improve from 0.80948
# Epoch 40/40
# 1999/1999 - 30s - loss: 0.3006 - accuracy: 0.9257 - val_loss: 0.6055 - val_accuracy: 0.8060
#
# Epoch 00040: val_accuracy did not improve from 0.80948

# %%
acc = historyr.history['accuracy']
val_acc = historyr.history['val_accuracy']
loss = historyr.history['loss']
val_loss = historyr.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'g', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.ylim([.5,1])
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()


plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.ylim([.3,.7])
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
import sklearn

# %%
y_preds = rcnn.predict(X_test_pad, batch_size=32).round().astype(int)
print("Test accuracy score", sklearn.metrics.accuracy_score(y_test, y_preds))
# Out:
# Test accuracy score 0.8054601745004222

# %%
 from sklearn.metrics import f1_score
 f1_sc=f1_score(y_test, y_preds, average='binary')
 f1_sc
# Out:
# 0.7936962750716332

# %%
p=precision_score(y_test, y_preds, average='binary')
p
# Out:
# 0.7639623075155136

# %%
r=recall_score(y_test, y_preds, average='binary')
r
# Out:
# 0.8258385093167702

# %% [markdown]
# **Simple LSTM**

# %%
model = Sequential()
model.add(embedding_layer)
model.add(LSTM(64, dropout=0.2, recurrent_dropout=0.25))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

print('Summary of the built model...')
print(model.summary())
# Out:
# Summary of the built model...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 25, 100)           3278700
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                42240
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 3,321,005
# Trainable params: 42,305
# Non-trainable params: 3,278,700
# _________________________________________________________________
# None

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

mc = tf.keras.callbacks.ModelCheckpoint('lstm_best.hdf5', monitor='val_accuracy', 
                                        verbose=1, save_best_only=True, mode='max')
es = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", mode="max", patience=5)
    
history = model.fit(X_train_pad, y_train,
                    epochs=40, callbacks=[mc], 
                    validation_split=0.1, verbose=2)
# Out:
# Epoch 1/40
# 1999/1999 - 65s - loss: 0.6106 - accuracy: 0.6649 - val_loss: 0.5656 - val_accuracy: 0.6933
#
# Epoch 00001: val_accuracy improved from -inf to 0.69326, saving model to lstm_best.hdf5
# Epoch 2/40
# 1999/1999 - 64s - loss: 0.5556 - accuracy: 0.7099 - val_loss: 0.5298 - val_accuracy: 0.7204
#
# Epoch 00002: val_accuracy improved from 0.69326 to 0.72042, saving model to lstm_best.hdf5
# Epoch 3/40
# 1999/1999 - 64s - loss: 0.5238 - accuracy: 0.7343 - val_loss: 0.5096 - val_accuracy: 0.7386
#
# Epoch 00003: val_accuracy improved from 0.72042 to 0.73857, saving model to lstm_best.hdf5
# Epoch 4/40
# 1999/1999 - 63s - loss: 0.5050 - accuracy: 0.7490 - val_loss: 0.5083 - val_accuracy: 0.7411
#
# Epoch 00004: val_accuracy improved from 0.73857 to 0.74110, saving model to lstm_best.hdf5
# Epoch 5/40
# 1999/1999 - 64s - loss: 0.4888 - accuracy: 0.7595 - val_loss: 0.4813 - val_accuracy: 0.7584
#
# Epoch 00005: val_accuracy improved from 0.74110 to 0.75841, saving model to lstm_best.hdf5
# Epoch 6/40
# 1999/1999 - 64s - loss: 0.4744 - accuracy: 0.7679 - val_loss: 0.4784 - val_accuracy: 0.7605
#
# Epoch 00006: val_accuracy improved from 0.75841 to 0.76052, saving model to lstm_best.hdf5
# Epoch 7/40
# 1999/1999 - 64s - loss: 0.4615 - accuracy: 0.7769 - val_loss: 0.4705 - val_accuracy: 0.7746
#
# Epoch 00007: val_accuracy improved from 0.76052 to 0.77459, saving model to lstm_best.hdf5
# Epoch 8/40
# 1999/1999 - 64s - loss: 0.4530 - accuracy: 0.7832 - val_loss: 0.4747 - val_accuracy: 0.7663
#
# Epoch 00008: val_accuracy did not improve from 0.77459
# Epoch 9/40
# 1999/1999 - 64s - loss: 0.4446 - accuracy: 0.7873 - val_loss: 0.4604 - val_accuracy: 0.7742
#
# Epoch 00009: val_accuracy did not improve from 0.77459
# Epoch 10/40
# 1999/1999 - 64s - loss: 0.4351 - accuracy: 0.7905 - val_loss: 0.4610 - val_accuracy: 0.7735
#
# Epoch 00010: val_accuracy did not improve from 0.77459
# Epoch 11/40
# 1999/1999 - 64s - loss: 0.4254 - accuracy: 0.7973 - val_loss: 0.4598 - val_accuracy: 0.7794
#
# Epoch 00011: val_accuracy improved from 0.77459 to 0.77937, saving model to lstm_best.hdf5
# Epoch 12/40
# 1999/1999 - 64s - loss: 0.4215 - accuracy: 0.7985 - val_loss: 0.4580 - val_accuracy: 0.7811
#
# Epoch 00012: val_accuracy improved from 0.77937 to 0.78106, saving model to lstm_best.hdf5
# Epoch 13/40
# 1999/1999 - 64s - loss: 0.4153 - accuracy: 0.8017 - val_loss: 0.4491 - val_accuracy: 0.7916
#
# Epoch 00013: val_accuracy improved from 0.78106 to 0.79161, saving model to lstm_best.hdf5
# Epoch 14/40
# 1999/1999 - 65s - loss: 0.4119 - accuracy: 0.8049 - val_loss: 0.4571 - val_accuracy: 0.7813
#
# Epoch 00014: val_accuracy did not improve from 0.79161
# Epoch 15/40
# 1999/1999 - 64s - loss: 0.4066 - accuracy: 0.8088 - val_loss: 0.4447 - val_accuracy: 0.7923
#
# Epoch 00015: val_accuracy improved from 0.79161 to 0.79232, saving model to lstm_best.hdf5
# Epoch 16/40
# 1999/1999 - 64s - loss: 0.4001 - accuracy: 0.8115 - val_loss: 0.4562 - val_accuracy: 0.7892
#
# Epoch 00016: val_accuracy did not improve from 0.79232
# Epoch 17/40
# 1999/1999 - 63s - loss: 0.3995 - accuracy: 0.8128 - val_loss: 0.4608 - val_accuracy: 0.7915
#
# Epoch 00017: val_accuracy did not improve from 0.79232
# Epoch 18/40
# 1999/1999 - 64s - loss: 0.3966 - accuracy: 0.8135 - val_loss: 0.4434 - val_accuracy: 0.7912
#
# Epoch 00018: val_accuracy did not improve from 0.79232
# Epoch 19/40
# 1999/1999 - 64s - loss: 0.3916 - accuracy: 0.8181 - val_loss: 0.4415 - val_accuracy: 0.7905
#
# Epoch 00019: val_accuracy did not improve from 0.79232
# Epoch 20/40
# 1999/1999 - 63s - loss: 0.3905 - accuracy: 0.8189 - val_loss: 0.4453 - val_accuracy: 0.7941
#
# Epoch 00020: val_accuracy improved from 0.79232 to 0.79415, saving model to lstm_best.hdf5
# Epoch 21/40
# 1999/1999 - 63s - loss: 0.3879 - accuracy: 0.8205 - val_loss: 0.4391 - val_accuracy: 0.7975
#
# Epoch 00021: val_accuracy improved from 0.79415 to 0.79752, saving model to lstm_best.hdf5
# Epoch 22/40
# 1999/1999 - 64s - loss: 0.3850 - accuracy: 0.8205 - val_loss: 0.4431 - val_accuracy: 0.7974
#
# Epoch 00022: val_accuracy did not improve from 0.79752
# Epoch 23/40
# 1999/1999 - 64s - loss: 0.3818 - accuracy: 0.8230 - val_loss: 0.4374 - val_accuracy: 0.7989
#
# Epoch 00023: val_accuracy improved from 0.79752 to 0.79893, saving model to lstm_best.hdf5
# Epoch 24/40
# 1999/1999 - 64s - loss: 0.3788 - accuracy: 0.8236 - val_loss: 0.4413 - val_accuracy: 0.7974
#
# Epoch 00024: val_accuracy did not improve from 0.79893
# Epoch 25/40
# 1999/1999 - 64s - loss: 0.3770 - accuracy: 0.8266 - val_loss: 0.4376 - val_accuracy: 0.8013
#
# Epoch 00025: val_accuracy improved from 0.79893 to 0.80132, saving model to lstm_best.hdf5
# Epoch 26/40
# 1999/1999 - 64s - loss: 0.3753 - accuracy: 0.8264 - val_loss: 0.4544 - val_accuracy: 0.7941
#
# Epoch 00026: val_accuracy did not improve from 0.80132
# Epoch 27/40
# 1999/1999 - 64s - loss: 0.3741 - accuracy: 0.8275 - val_loss: 0.4328 - val_accuracy: 0.8047
#
# Epoch 00027: val_accuracy improved from 0.80132 to 0.80470, saving model to lstm_best.hdf5
# Epoch 28/40
# 1999/1999 - 64s - loss: 0.3742 - accuracy: 0.8257 - val_loss: 0.4344 - val_accuracy: 0.8037
#
# Epoch 00028: val_accuracy did not improve from 0.80470
# Epoch 29/40
# 1999/1999 - 64s - loss: 0.3721 - accuracy: 0.8289 - val_loss: 0.4251 - val_accuracy: 0.8070
#
# Epoch 00029: val_accuracy improved from 0.80470 to 0.80695, saving model to lstm_best.hdf5
# Epoch 30/40
# 1999/1999 - 64s - loss: 0.3681 - accuracy: 0.8302 - val_loss: 0.4217 - val_accuracy: 0.8043
#
# Epoch 00030: val_accuracy did not improve from 0.80695
# Epoch 31/40
# 1999/1999 - 63s - loss: 0.3685 - accuracy: 0.8296 - val_loss: 0.4285 - val_accuracy: 0.8055
#
# Epoch 00031: val_accuracy did not improve from 0.80695
# Epoch 32/40
# 1999/1999 - 64s - loss: 0.3670 - accuracy: 0.8299 - val_loss: 0.4279 - val_accuracy: 0.8019
#
# Epoch 00032: val_accuracy did not improve from 0.80695
# Epoch 33/40
# 1999/1999 - 65s - loss: 0.3659 - accuracy: 0.8322 - val_loss: 0.4361 - val_accuracy: 0.8071
#
# Epoch 00033: val_accuracy improved from 0.80695 to 0.80709, saving model to lstm_best.hdf5
# Epoch 34/40
# 1999/1999 - 64s - loss: 0.3617 - accuracy: 0.8315 - val_loss: 0.4303 - val_accuracy: 0.8082
#
# Epoch 00034: val_accuracy improved from 0.80709 to 0.80822, saving model to lstm_best.hdf5
# Epoch 35/40
# 1999/1999 - 64s - loss: 0.3643 - accuracy: 0.8310 - val_loss: 0.4324 - val_accuracy: 0.8043
#
# Epoch 00035: val_accuracy did not improve from 0.80822
# Epoch 36/40
# 1999/1999 - 64s - loss: 0.3629 - accuracy: 0.8327 - val_loss: 0.4330 - val_accuracy: 0.8109
#
# Epoch 00036: val_accuracy improved from 0.80822 to 0.81089, saving model to lstm_best.hdf5
# Epoch 37/40
# 1999/1999 - 65s - loss: 0.3598 - accuracy: 0.8356 - val_loss: 0.4330 - val_accuracy: 0.8050
#
# Epoch 00037: val_accuracy did not improve from 0.81089
# Epoch 38/40
# 1999/1999 - 64s - loss: 0.3561 - accuracy: 0.8360 - val_loss: 0.4281 - val_accuracy: 0.8082
#
# Epoch 00038: val_accuracy did not improve from 0.81089
# Epoch 39/40
# 1999/1999 - 64s - loss: 0.3584 - accuracy: 0.8345 - val_loss: 0.4308 - val_accuracy: 0.8098
#
# Epoch 00039: val_accuracy did not improve from 0.81089
# Epoch 40/40
# 1999/1999 - 64s - loss: 0.3549 - accuracy: 0.8366 - val_loss: 0.4209 - val_accuracy: 0.8062
#
# Epoch 00040: val_accuracy did not improve from 0.81089

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'g', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.ylim([.65,1])
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()


plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.ylim([.25,.7])
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
import sklearn

# %%
y_preds = model.predict(X_test_pad, batch_size=32).round().astype(int)
print("Test accuracy score", sklearn.metrics.accuracy_score(y_test, y_preds))
# Out:
# Test accuracy score 0.8123839009287925

# %%
 from sklearn.metrics import f1_score
 f1_sc=f1_score(y_test, y_preds, average='binary')
 f1_sc
# Out:
# 0.8026993429231042

# %%
p=precision_score(y_test, y_preds, average='binary')
p
# Out:
# 0.7667081307248671

# %%
r=recall_score(y_test, y_preds, average='binary')
r
# Out:
# 0.8422360248447205

# %% [markdown]
# **BiLSTM**

# %%
model1 = Sequential()
model1.add(embedding_layer)
model1.add(Bidirectional(tf.keras.layers.LSTM(64)))
#model1.add(GlobalMaxPool1D())
model1.add(Dense(64, activation='relu'))
model1.add(Dropout(0.4))
model1.add(Dense(32, activation='relu'))
model1.add(Dropout(0.4))
model1.add(Dense(1, activation='sigmoid'))

#model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

print('Summary of the built model...')
print(model1.summary())
# Out:
# Summary of the built model...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 25, 100)           3278700
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 128)               84480
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 3,373,549
# Trainable params: 94,849
# Non-trainable params: 3,278,700
# _________________________________________________________________
# None

# %%
plot_model(model1, to_file='model_plot1.png', show_shapes=True, show_layer_names=True)

# %%
model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

mc1 = tf.keras.callbacks.ModelCheckpoint('bilstm_best.hdf5', monitor='val_accuracy', 
                                        verbose=1, save_best_only=True, mode='max')
es = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", mode="max", patience=5)
    
history1 = model1.fit(X_train_pad, y_train,
                    epochs=40, callbacks=[mc1], 
                    validation_split=0.1, verbose=2)
# Out:
# Epoch 1/40
# 1999/1999 - 51s - loss: 0.5958 - accuracy: 0.6764 - val_loss: 0.5479 - val_accuracy: 0.7080
#
# Epoch 00001: val_accuracy improved from -inf to 0.70803, saving model to bilstm_best.hdf5
# Epoch 2/40
# 1999/1999 - 47s - loss: 0.5185 - accuracy: 0.7398 - val_loss: 0.5020 - val_accuracy: 0.7426
#
# Epoch 00002: val_accuracy improved from 0.70803 to 0.74265, saving model to bilstm_best.hdf5
# Epoch 3/40
# 1999/1999 - 47s - loss: 0.4606 - accuracy: 0.7802 - val_loss: 0.4860 - val_accuracy: 0.7608
#
# Epoch 00003: val_accuracy improved from 0.74265 to 0.76080, saving model to bilstm_best.hdf5
# Epoch 4/40
# 1999/1999 - 47s - loss: 0.4086 - accuracy: 0.8109 - val_loss: 0.4747 - val_accuracy: 0.7725
#
# Epoch 00004: val_accuracy improved from 0.76080 to 0.77248, saving model to bilstm_best.hdf5
# Epoch 5/40
# 1999/1999 - 47s - loss: 0.3620 - accuracy: 0.8364 - val_loss: 0.4552 - val_accuracy: 0.7885
#
# Epoch 00005: val_accuracy improved from 0.77248 to 0.78852, saving model to bilstm_best.hdf5
# Epoch 6/40
# 1999/1999 - 48s - loss: 0.3203 - accuracy: 0.8575 - val_loss: 0.4733 - val_accuracy: 0.7996
#
# Epoch 00006: val_accuracy improved from 0.78852 to 0.79963, saving model to bilstm_best.hdf5
# Epoch 7/40
# 1999/1999 - 47s - loss: 0.2823 - accuracy: 0.8769 - val_loss: 0.5223 - val_accuracy: 0.8017
#
# Epoch 00007: val_accuracy improved from 0.79963 to 0.80174, saving model to bilstm_best.hdf5
# Epoch 8/40
# 1999/1999 - 47s - loss: 0.2477 - accuracy: 0.8919 - val_loss: 0.5417 - val_accuracy: 0.8043
#
# Epoch 00008: val_accuracy improved from 0.80174 to 0.80428, saving model to bilstm_best.hdf5
# Epoch 9/40
# 1999/1999 - 47s - loss: 0.2242 - accuracy: 0.9042 - val_loss: 0.5206 - val_accuracy: 0.8126
#
# Epoch 00009: val_accuracy improved from 0.80428 to 0.81258, saving model to bilstm_best.hdf5
# Epoch 10/40
# 1999/1999 - 47s - loss: 0.1974 - accuracy: 0.9162 - val_loss: 0.6247 - val_accuracy: 0.8037
#
# Epoch 00010: val_accuracy did not improve from 0.81258
# Epoch 11/40
# 1999/1999 - 48s - loss: 0.1821 - accuracy: 0.9222 - val_loss: 0.5943 - val_accuracy: 0.8214
#
# Epoch 00011: val_accuracy improved from 0.81258 to 0.82144, saving model to bilstm_best.hdf5
# Epoch 12/40
# 1999/1999 - 48s - loss: 0.1635 - accuracy: 0.9314 - val_loss: 0.6275 - val_accuracy: 0.8158
#
# Epoch 00012: val_accuracy did not improve from 0.82144
# Epoch 13/40
# 1999/1999 - 48s - loss: 0.1495 - accuracy: 0.9377 - val_loss: 0.7196 - val_accuracy: 0.8269
#
# Epoch 00013: val_accuracy improved from 0.82144 to 0.82693, saving model to bilstm_best.hdf5
# Epoch 14/40
# 1999/1999 - 47s - loss: 0.1400 - accuracy: 0.9417 - val_loss: 0.7963 - val_accuracy: 0.8234
#
# Epoch 00014: val_accuracy did not improve from 0.82693
# Epoch 15/40
# 1999/1999 - 48s - loss: 0.1267 - accuracy: 0.9474 - val_loss: 0.7558 - val_accuracy: 0.8230
#
# Epoch 00015: val_accuracy did not improve from 0.82693
# Epoch 16/40
# 1999/1999 - 48s - loss: 0.1165 - accuracy: 0.9531 - val_loss: 0.8572 - val_accuracy: 0.8271
#
# Epoch 00016: val_accuracy improved from 0.82693 to 0.82707, saving model to bilstm_best.hdf5
# Epoch 17/40
# 1999/1999 - 48s - loss: 0.1070 - accuracy: 0.9561 - val_loss: 0.8561 - val_accuracy: 0.8289
#
# Epoch 00017: val_accuracy improved from 0.82707 to 0.82890, saving model to bilstm_best.hdf5
# Epoch 18/40
# 1999/1999 - 49s - loss: 0.1000 - accuracy: 0.9594 - val_loss: 0.9174 - val_accuracy: 0.8255
#
# Epoch 00018: val_accuracy did not improve from 0.82890
# Epoch 19/40
# 1999/1999 - 49s - loss: 0.0923 - accuracy: 0.9629 - val_loss: 0.9394 - val_accuracy: 0.8268
#
# Epoch 00019: val_accuracy did not improve from 0.82890
# Epoch 20/40
# 1999/1999 - 51s - loss: 0.0872 - accuracy: 0.9646 - val_loss: 1.0035 - val_accuracy: 0.8290
#
# Epoch 00020: val_accuracy improved from 0.82890 to 0.82904, saving model to bilstm_best.hdf5
# Epoch 21/40
# 1999/1999 - 50s - loss: 0.0792 - accuracy: 0.9670 - val_loss: 1.0486 - val_accuracy: 0.8272
#
# Epoch 00021: val_accuracy did not improve from 0.82904
# Epoch 22/40
# 1999/1999 - 50s - loss: 0.0785 - accuracy: 0.9688 - val_loss: 0.9992 - val_accuracy: 0.8324
#
# Epoch 00022: val_accuracy improved from 0.82904 to 0.83242, saving model to bilstm_best.hdf5
# Epoch 23/40
# 1999/1999 - 52s - loss: 0.0699 - accuracy: 0.9724 - val_loss: 1.0673 - val_accuracy: 0.8299
#
# Epoch 00023: val_accuracy did not improve from 0.83242
# Epoch 24/40
# 1999/1999 - 51s - loss: 0.0682 - accuracy: 0.9728 - val_loss: 1.1438 - val_accuracy: 0.8326
#
# Epoch 00024: val_accuracy improved from 0.83242 to 0.83256, saving model to bilstm_best.hdf5
# Epoch 25/40
# 1999/1999 - 51s - loss: 0.0625 - accuracy: 0.9753 - val_loss: 1.1060 - val_accuracy: 0.8314
#
# Epoch 00025: val_accuracy did not improve from 0.83256
# Epoch 26/40
# 1999/1999 - 49s - loss: 0.0606 - accuracy: 0.9764 - val_loss: 1.1365 - val_accuracy: 0.8328
#
# Epoch 00026: val_accuracy improved from 0.83256 to 0.83284, saving model to bilstm_best.hdf5
# Epoch 27/40
# 1999/1999 - 49s - loss: 0.0548 - accuracy: 0.9791 - val_loss: 1.2412 - val_accuracy: 0.8319
#
# Epoch 00027: val_accuracy did not improve from 0.83284
# Epoch 28/40
# 1999/1999 - 50s - loss: 0.0559 - accuracy: 0.9790 - val_loss: 1.2661 - val_accuracy: 0.8340
#
# Epoch 00028: val_accuracy improved from 0.83284 to 0.83397, saving model to bilstm_best.hdf5
# Epoch 29/40
# 1999/1999 - 49s - loss: 0.0518 - accuracy: 0.9805 - val_loss: 1.4178 - val_accuracy: 0.8361
#
# Epoch 00029: val_accuracy improved from 0.83397 to 0.83608, saving model to bilstm_best.hdf5
# Epoch 30/40
# 1999/1999 - 49s - loss: 0.0510 - accuracy: 0.9806 - val_loss: 1.2061 - val_accuracy: 0.8303
#
# Epoch 00030: val_accuracy did not improve from 0.83608
# Epoch 31/40
# 1999/1999 - 49s - loss: 0.0486 - accuracy: 0.9821 - val_loss: 1.3247 - val_accuracy: 0.8304
#
# Epoch 00031: val_accuracy did not improve from 0.83608
# Epoch 32/40
# 1999/1999 - 48s - loss: 0.0455 - accuracy: 0.9833 - val_loss: 1.3135 - val_accuracy: 0.8378
#
# Epoch 00032: val_accuracy improved from 0.83608 to 0.83777, saving model to bilstm_best.hdf5
# Epoch 33/40
# 1999/1999 - 48s - loss: 0.0450 - accuracy: 0.9838 - val_loss: 1.2850 - val_accuracy: 0.8368
#
# Epoch 00033: val_accuracy did not improve from 0.83777
# Epoch 34/40
# 1999/1999 - 49s - loss: 0.0428 - accuracy: 0.9841 - val_loss: 1.4367 - val_accuracy: 0.8278
#
# Epoch 00034: val_accuracy did not improve from 0.83777
# Epoch 35/40
# 1999/1999 - 50s - loss: 0.0417 - accuracy: 0.9839 - val_loss: 1.2337 - val_accuracy: 0.8314
#
# Epoch 00035: val_accuracy did not improve from 0.83777
# Epoch 36/40
# 1999/1999 - 51s - loss: 0.0385 - accuracy: 0.9859 - val_loss: 1.2772 - val_accuracy: 0.8302
#
# Epoch 00036: val_accuracy did not improve from 0.83777
# Epoch 37/40
# 1999/1999 - 50s - loss: 0.0380 - accuracy: 0.9860 - val_loss: 1.3736 - val_accuracy: 0.8299
#
# Epoch 00037: val_accuracy did not improve from 0.83777
# Epoch 38/40
# 1999/1999 - 50s - loss: 0.0376 - accuracy: 0.9859 - val_loss: 1.3697 - val_accuracy: 0.8350
#
# Epoch 00038: val_accuracy did not improve from 0.83777
# Epoch 39/40
# 1999/1999 - 49s - loss: 0.0350 - accuracy: 0.9868 - val_loss: 1.4672 - val_accuracy: 0.8302
#
# Epoch 00039: val_accuracy did not improve from 0.83777
# Epoch 40/40
# 1999/1999 - 50s - loss: 0.0358 - accuracy: 0.9870 - val_loss: 1.2754 - val_accuracy: 0.8309
#
# Epoch 00040: val_accuracy did not improve from 0.83777

# %%
acc = history1.history['accuracy']
val_acc = history1.history['val_accuracy']
loss = history1.history['loss']
val_loss = history1.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'g', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.ylim([.65,1.0])
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()


plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.ylim([.0,1.8])
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
import sklearn

# %%
y_preds1 = model1.predict(X_test_pad, batch_size=32).round().astype(int)
print("Test accuracy score", sklearn.metrics.accuracy_score(y_test, y_preds1))

# %%
y_preds1.shape

# %%
matrix = confusion_matrix(y_test, y_preds1)
print(matrix)

# %%
f1_sc1=f1_score(y_test, y_preds1, average='binary')
f1_sc1

# %%
p1=precision_score(y_test, y_preds1, average='binary')
p1

# %%
r1=recall_score(y_test, y_preds1, average='binary')
r1

# %% [markdown]
# **BiGRU**

# %%
model2 = Sequential()
model2.add(embedding_layer)
model2.add(Bidirectional(tf.keras.layers.GRU(64)))
#model2.add(GlobalMaxPool1D())
model2.add(Dense(32, activation='relu'))
model2.add(Dropout(0.2))
#model2.add(Dense(32, activation='relu'))
#model2.add(Dropout(0.4))
model2.add(Dense(1, activation='sigmoid'))

#model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

print('Summary of the built model...')
print(model2.summary())

# %%
plot_model(model2, to_file='model_plot2.png', show_shapes=True, show_layer_names=True)

# %%
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

mc2 = tf.keras.callbacks.ModelCheckpoint('bigru_best.hdf5', monitor='val_accuracy', 
                                        verbose=1, save_best_only=True, mode='max')
es = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", mode="max", patience=5)
    
history2 = model2.fit(X_train_pad, y_train,
                    epochs=40, callbacks=[mc2], 
                    validation_split=0.1, verbose=2)

# %%
acc = history2.history['accuracy']
val_acc = history2.history['val_accuracy']
loss = history2.history['loss']
val_loss = history2.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'g', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.ylim([.65,1.0])
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()


plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.ylim([.0,1.8])
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
import sklearn

# %%
y_preds2 = model2.predict(X_test_pad).round().astype(int)
print("Test accuracy score", sklearn.metrics.accuracy_score(y_test, y_preds2))

# %%
y_preds2.shape

# %%
matrix = confusion_matrix(y_test, y_preds2)
print(matrix)

# %%
f1_sc2=f1_score(y_test, y_preds2, average='binary')
f1_sc2

# %%
p2=precision_score(y_test, y_preds2, average='binary')
p2

# %%
r2=recall_score(y_test, y_preds2, average='binary')
r2

# %%
def lsp(s):
  pred=model.predict(s)
  pred*=100
  return pred[0][0]

# %%
def bilsp(s):
  pred=model1.predict(s)
  pred*=100
  return pred[0][0]

# %%
def bigrp(s):
  pred=model2.predict(s)
  pred*=100
  return pred[0][0]

# %%
def rc(s):
  pred=rcnn.predict(s)
  pred*=100
  return pred[0][0]

# %%
def predict_sarcasm(s):
    x_final = pd.DataFrame({"headline":[s]})
    test_lines = CleanTokenize(x_final)
    test_sequences = tokenizer_obj.texts_to_sequences(test_lines)
    test_review_pad = pad_sequences(test_sequences, maxlen=max_length, padding='post')
    pred = rc(test_review_pad)*0.2+lsp(test_review_pad)*0.22+ bilsp(test_review_pad)*0.31 +bigrp( test_review_pad)*0.27
    #print(pred[0][0])
    if pred>=55: return "That was sarcastic"
    elif pred<55: return "Seems like it wasn't sarcastic"

# %%
predict_sarcasm("Hello, I'm new here. Please take good care of me")

# %%
predict_mod("I was asked if I would kill my best friend for ! million. Now my family is rich and I'm in prison.")

# %%
"""with open("/content/drive/MyDrive/sample.txt") as fp:
  lines=fp.readlines()
  count=0
  c=0
  for l in lines:
    token=l.lower().strip().split('\t')
    val=int(token[1])
    res=predict_sarcasm(token[0])
    if val==res:
      count+=1
    c+=1
    print("{}-->accuracy: {}".format(c,count/c))
  tst_acc=count/7500
  print(tst_acc)"""

# %%
print(tst_acc)

# %%
with open("/content/drive/MyDrive/hhh.txt") as fp:
  lines=fp.readlines()
  count=0
  c=1
  for l in lines:
    print(l+"--{}".format(predict_sarcasm(l)))

# %%
# !pip install jupyter-dash

# %%
import plotly.express as px
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output, State # Load Data

# %%
df = px.data.tips()# Build App
#app = JupyterDash(__name__)
val="text goes here..."

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = JupyterDash(__name__, external_stylesheets=external_stylesheets)

app.layout = html.Div([
    html.H2("Sarcasm Detector", style= {'textAlign' : 'center', 'position' : 'absolute'  , 'left' : '50%', 'top' : '5%', '-ms-transform': 'translateX(-50%)', 'transform': 'translateX(-50%)'}),
               
    dcc.Input(id='my-id', value=val, type="text", size="50", style={ 'textAlign' : 'center', 'position' : 'absolute' ,  'left' : '50%' , 'top' : '20%', '-ms-transform': 'translateX(-50%)', 'transform': 'translateX(-50%)'}),
    html.Br(),
    html.Br(),
    html.Button('Get Result', id='button', style= {'margin': '0', 'background-color' : '#add8e6', 'color' : '#000000', 'text-align' : 'center' , 'position' : 'absolute' ,  'left' : '50%' , 'top' : '30%', '-ms-transform': 'translateX(-50%)', 'transform': 'translateX(-50%)'}),
    html.Div(id='my-div', style={'text-color' : '#ff0000', 'text-allign' : 'center','position' : 'absolute' ,  'left' : '50%' , 'top' : '40%', 'font-size' : '40px', '-ms-transform': 'translateX(-50%)', 'transform': 'translateX(-50%)'})
])

@app.callback(
    Output(component_id='my-div', component_property='children'),
    [Input('button', 'n_clicks')],
    state=[State(component_id='my-id', component_property='value')]
)

def update_output_div(n_clicks, input_value):
    if input_value == val or input_value=='': 
      return ""
    return predict_sarcasm(input_value)


if __name__ == '__main__':
    app.run_server(debug=True)

# %%
! pip install pyngrok

# %%
! ngrok authtoken 1osKwlasZuNGTKi085dhP6uhU14_444ixSr1bhxaNqMburgUX

# %%
from pyngrok import ngrok

# Open a HTTP tunnel on the default port 80
public_url = ngrok.connect(8050, 'http')

# %%
public_url

# %%
ngrok.kill()
